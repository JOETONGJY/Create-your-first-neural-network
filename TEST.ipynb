# %%
import torch
torch.__version__
# Out:
# '2.4.1'

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# D:\anaconda3\envs\systemapp\python38.zip
# D:\anaconda3\envs\systemapp\DLLs
# D:\anaconda3\envs\systemapp\lib
# D:\anaconda3\envs\systemapp
#
# C:\Users\pc\AppData\Roaming\Python\Python38\site-packages
# D:\anaconda3\envs\systemapp\lib\site-packages
# D:\anaconda3\envs\systemapp\lib\site-packages\win32
# D:\anaconda3\envs\systemapp\lib\site-packages\win32\lib
# D:\anaconda3\envs\systemapp\lib\site-packages\Pythonwin

# %%
import os
for root, dirs, files in os.walk('D:\\anaconda3\\envs\\systemapp'):
    for name in files:
        if name.endswith('.pth'):
            print(os.path.join(root, name))
# Out:
# D:\anaconda3\envs\systemapp\Lib\site-packages\pywin32.pth

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu117'

# %%
import sys
sys.executable
# Out:
# 'D:\\anaconda3\\envs\\systemapp\\python.exe'

# %%
import torch

torch.__version__
# Out:
# '2.4.1'
